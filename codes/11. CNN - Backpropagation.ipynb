# %% [markdown]
# # IIC-2433 Minería de Datos UC

# %% [markdown]
# # CNN para reconocer dígitos

# %%
from IPython.display import Image
Image(filename='lenet.png')

# %% [markdown]
# ### Vamos a trabajar en tensorflow

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ### Cargamos los datos

# %%
train_data = pd.read_csv('train.csv')

# %% [markdown]
# ### Nos quedamos solo con los datos en X (imágenes) y dejamos en Y la variable objetivo

# %%
X_train = train_data.drop(columns=['label']).values / 255.0
Y_train = train_data['label'].values

# %%
X_train.shape
# Out:
# (42000, 784)

# %% [markdown]
# ### Hacemos un reshape ya que cada imagen es de 28 x 28

# %%
X_train = X_train.reshape(-1, 28, 28, 1)

# %%
X_train.shape
# Out:
# (42000, 28, 28, 1)

# %% [markdown]
# ### Vamos a crear una partición de validación desde training para no usar la partición de test

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=46)

# %% [markdown]
# ### Esta es una función que hace aumento de datos aplicando transformaciones sobre las imágenes (rotaciones, zoom, ...)

# %%
datagen = ImageDataGenerator(
    rotation_range=10, # Degree range for random rotations.
    zoom_range=0.1, # Range for random zoom
    width_shift_range=0.1, # fraction of total width (traslation)
    height_shift_range=0.1, # fraction of total height (traslation)
    horizontal_flip=False, # Randomly flip inputs horizontally.
    vertical_flip=False # Randomly flip inputs vertically.
)
datagen.fit(X_train)

# %% [markdown]
# ### Vamos a declarar la arquitectura de la red con la estrategia 'sequential'

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(5, 5), padding='Same', activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(32, kernel_size=(5, 5), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='Same', activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))

# %% [markdown]
# ### Vamos a usar adam para tener learning rate adaptivo

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Y el learning rate los vamos a modificar según el accuracy en validación

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.00001)

# %% [markdown]
# ### Al ingestar imágenes con data generator, hacemos aumento de datos en tiempo real durante el entrenamiento

# %%
history = model.fit(
    datagen.flow(X_train, Y_train, batch_size=64),
    epochs=20,
    validation_data=(X_val, Y_val),
    verbose=2,
    steps_per_epoch=X_train.shape[0] // 64,
    callbacks=[learning_rate_reduction]
)
# Out:
# Epoch 1/20
# 590/590 - 28s - loss: 0.3792 - accuracy: 0.8775 - val_loss: 0.0514 - val_accuracy: 0.9845 - lr: 0.0010 - 28s/epoch - 48ms/step
# Epoch 2/20
# 590/590 - 28s - loss: 0.1289 - accuracy: 0.9614 - val_loss: 0.0460 - val_accuracy: 0.9860 - lr: 0.0010 - 28s/epoch - 47ms/step
# Epoch 3/20
# 590/590 - 27s - loss: 0.0970 - accuracy: 0.9714 - val_loss: 0.0313 - val_accuracy: 0.9898 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 4/20
# 590/590 - 27s - loss: 0.0803 - accuracy: 0.9762 - val_loss: 0.0440 - val_accuracy: 0.9867 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 5/20
# 590/590 - 27s - loss: 0.0753 - accuracy: 0.9780 - val_loss: 0.0338 - val_accuracy: 0.9902 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 6/20
# 590/590 - 27s - loss: 0.0661 - accuracy: 0.9807 - val_loss: 0.0272 - val_accuracy: 0.9907 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 7/20
# 590/590 - 27s - loss: 0.0623 - accuracy: 0.9812 - val_loss: 0.0243 - val_accuracy: 0.9926 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 8/20
# 590/590 - 27s - loss: 0.0576 - accuracy: 0.9835 - val_loss: 0.0228 - val_accuracy: 0.9936 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 9/20
# 590/590 - 27s - loss: 0.0534 - accuracy: 0.9838 - val_loss: 0.0217 - val_accuracy: 0.9933 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 10/20
# 590/590 - 27s - loss: 0.0482 - accuracy: 0.9857 - val_loss: 0.0170 - val_accuracy: 0.9950 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 11/20
# 590/590 - 27s - loss: 0.0491 - accuracy: 0.9858 - val_loss: 0.0153 - val_accuracy: 0.9952 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 12/20
# 590/590 - 27s - loss: 0.0452 - accuracy: 0.9868 - val_loss: 0.0226 - val_accuracy: 0.9938 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 13/20
# 590/590 - 27s - loss: 0.0461 - accuracy: 0.9864 - val_loss: 0.0192 - val_accuracy: 0.9945 - lr: 0.0010 - 27s/epoch - 47ms/step
# Epoch 14/20
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 590/590 - 27s - loss: 0.0436 - accuracy: 0.9870 - val_loss: 0.0166 - val_accuracy: 0.9936 - lr: 0.0010 - 27s/epoch - 46ms/step
# Epoch 15/20
# 590/590 - 27s - loss: 0.0332 - accuracy: 0.9907 - val_loss: 0.0133 - val_accuracy: 0.9955 - lr: 5.0000e-04 - 27s/epoch - 46ms/step
# Epoch 16/20
# 590/590 - 27s - loss: 0.0314 - accuracy: 0.9906 - val_loss: 0.0185 - val_accuracy: 0.9952 - lr: 5.0000e-04 - 27s/epoch - 46ms/step
# Epoch 17/20
# 590/590 - 27s - loss: 0.0289 - accuracy: 0.9916 - val_loss: 0.0167 - val_accuracy: 0.9955 - lr: 5.0000e-04 - 27s/epoch - 46ms/step
# Epoch 18/20
# 590/590 - 27s - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.0133 - val_accuracy: 0.9957 - lr: 5.0000e-04 - 27s/epoch - 46ms/step
# Epoch 19/20
# 590/590 - 27s - loss: 0.0279 - accuracy: 0.9919 - val_loss: 0.0143 - val_accuracy: 0.9948 - lr: 5.0000e-04 - 27s/epoch - 46ms/step
# Epoch 20/20
# 590/590 - 27s - loss: 0.0252 - accuracy: 0.9926 - val_loss: 0.0120 - val_accuracy: 0.9960 - lr: 5.0000e-04 - 27s/epoch - 46ms/step

# %%
loss, accuracy = model.evaluate(X_train, Y_train)
print("Final training loss: {:.8f}".format(loss))
print("Final training accuracy: {:.4%}".format(accuracy))
# Out:
# 1182/1182 [==============================] - 13s 11ms/step - loss: 0.0063 - accuracy: 0.9980
# Final training loss: 0.00627995
# Final training accuracy: 99.7989%

# %% [markdown]
# ### Finalmente miramos las curvas de accuracy y función de pérdida

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
