# %% [markdown]
# # IIC-2433 Minería de Datos UC

# %% [markdown]
# - Versiones de librerías, python >= 3.8.10
#
# - numpy ~ 1.20.3
# - sklearn ~ 1.0.2
# - matplotlib ~ 3.5.2

# %%
from sklearn import datasets, mixture
import matplotlib.pyplot as plt

faces = datasets.fetch_olivetti_faces()
X = faces.data

fig, axs = plt.subplots(nrows=20, ncols=20, figsize=(10, 10))
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(X[idx].reshape((64, 64)), cmap=plt.cm.copper)
    ax.axis("off")
_ = fig.suptitle("Faces dataset", fontsize=12)

# %% [markdown]
# ## Actividad en clase
#
# Usando el algoritmo **GMM**, haga lo siguiente:
#
# - Reduzca la dimensionalidad del dataset usando **PCA** para retener el 95% de la varianza de X.
# - Calcule la curva **AIC** para n en {1,250} en intervalos de 5 y seleccione el número de componentes de la mezcla.
# - Ajuste **GMM** usando el número de componentes seleccionado en el paso anterior y covariance type = full.
# - Genere 100 muestras usando **GMM**.
# - Dibuje los datos generados por el modelo en un arreglo de 10 x 10.
# - Encuentre algunas caras 'creíbles' que no se encuentran en el dataset original.
# - ¿Por qué algunas caras son no creíbles?
# - Cuanto termine, me avisa para entregarle una **L (logrado)**.
# - Recuerde que cada L es una décima más en la nota de la asignatura.
# - Pueden trabajar de a dos.
#
# ***Tiene hasta el final de la clase.***
