# %% [markdown]
# # IIC-2433 Minería de Datos UC

# %% [markdown]
# - Versiones de librerías, python 3.8.10
#
# - numpy 1.20.3
# - sklearn 1.0.2
# - matplotlib 3.5.2

# %%
from sklearn import datasets

faces = datasets.fetch_olivetti_faces()
X = faces.data
y = faces.target
print(X.data.shape)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data
# (400, 4096)

# %% [markdown]
# ## Actividad en clase
#
# Vamos a trabajar este dataset usando **PCA**. Para esto haga lo siguiente:
#
# - Aplique min-max scaler al dataset.
# - Descomponga el dataset en la máxima cantidad de componentes que se pueda. ¿Cuántas son?
# - Transforme el dataset con PCA para retener el 95% de la varianza.
# - ¿Cuántas componentes quedaron al retener el 95% de la varianza?
# - Cuanto termine, me avisa para entregarle una **L (logrado)**.
# - Recuerde que las L otorgan un bono en la nota final de la asignatura.
# - Pueden trabajar de a dos.
#
# ***Tiene hasta el final de la clase.***

# %% [markdown]
# ### Aplicamos MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# %% [markdown]
# ### Descomponemos a 400

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=400)
pca.fit(X)
# Out:
# PCA(n_components=400)

# %% [markdown]
# ### Calculamos cuántas componentes retienen el 95% de la varianza

# %%
def min_var(v,exp_var):
    acc = 0
    i=0
    while acc < v:
        acc += exp_var[i]
        i += 1
    return i


## Calculamos las compoenntes para retener el 90% de la varianza del dataset original
min_var(0.95,pca.explained_variance_ratio_)
# Out:
# 121

# %% [markdown]
# ### Proyectamos usando PCA a k = 121

# %%
pca = PCA(n_components=121)
X_= pca.fit_transform(X)
